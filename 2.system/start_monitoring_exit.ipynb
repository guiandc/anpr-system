# %%
from initialize_functions import *
from request_functions import *

# %%
def monitoring_exit():
    while True:
        enter_image_list = os.listdir(paths['IMGS_EXIT'])
        if enter_image_list:
            prepared_IMG = prepareIMG(os.path.join(paths['IMGS_EXIT'], enter_image_list[0]))
            ocr_res = ocr(prepared_IMG[0], prepared_IMG[1], 0.2, 52)
            plate = format_ocr(ocr_res)
            print("SAIDA: " + plate)

# %%
monitoring_exit()
# Out:
# SAIDA: FBY2860
# SAIDA: FBY2860
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [6], line 1
# ----> 1 monitoring_exit()
#
# Cell In [5], line 6, in monitoring_exit()
#       4 if enter_image_list:
#       5     prepared_IMG = prepareIMG(os.path.join(paths['IMGS_EXIT'], enter_image_list[0]))
# ----> 6     ocr_res = ocr(prepared_IMG[0], prepared_IMG[1], 0.2, 52)
#       7     plate = format_ocr(ocr_res)
#       8     print("SAIDA: " + plate)
#
# File G:\Users\gui20\python_projects\ANPR_FINAL\2.system\initialize_functions.py:137, in ocr(image, detections, detection_threshold, value)
#     135 gray_image = cv2.cvtColor(crop, cv2.COLOR_BGR2GRAY)
#     136 (thresh, binary) = cv2.threshold(gray_image, value, 255, cv2.THRESH_BINARY_INV)
# --> 137 reader = easyocr.Reader(['en'], gpu=True, verbose=False)
#     138 ocr_result = reader.readtext(binary
#     139                            , allowlist = "ABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789"
#     140                            , text_threshold = 0
#    (...)
#     144                            , detail = 0
#     145                            , paragraph = 1)
#     146 return (ocr_result)
#
# File G:\Users\gui20\python_projects\ANPR_FINAL\anprsys\lib\site-packages\easyocr\easyocr.py:210, in Reader.__init__(self, lang_list, gpu, model_storage_directory, user_network_directory, detect_network, recog_network, download_enabled, detector, recognizer, verbose, quantize, cudnn_benchmark)
#     207     dict_list[lang] = os.path.join(BASE_PATH, 'dict', lang + ".txt")
#     209 if detector:
# --> 210     self.detector = self.initDetector(detector_path)
#     212 if recognizer:
#     213     if recog_network == 'generation1':
#
# File G:\Users\gui20\python_projects\ANPR_FINAL\anprsys\lib\site-packages\easyocr\easyocr.py:267, in Reader.initDetector(self, detector_path)
#     266 def initDetector(self, detector_path):
# --> 267     return self.get_detector(detector_path,
#     268                              device = self.device,
#     269                              quantize = self.quantize,
#     270                              cudnn_benchmark = self.cudnn_benchmark
#     271                              )
#
# File G:\Users\gui20\python_projects\ANPR_FINAL\anprsys\lib\site-packages\easyocr\detection.py:75, in get_detector(trained_model, device, quantize, cudnn_benchmark)
#      74 def get_detector(trained_model, device='cpu', quantize=True, cudnn_benchmark=False):
# ---> 75     net = CRAFT()
#      77     if device == 'cpu':
#      78         net.load_state_dict(copyStateDict(torch.load(trained_model, map_location=device)))
#
# File G:\Users\gui20\python_projects\ANPR_FINAL\anprsys\lib\site-packages\easyocr\craft.py:35, in CRAFT.__init__(self, pretrained, freeze)
#      32 super(CRAFT, self).__init__()
#      34 """ Base network """
# ---> 35 self.basenet = vgg16_bn(pretrained, freeze)
#      37 """ U network """
#      38 self.upconv1 = double_conv(1024, 512, 256)
#
# File G:\Users\gui20\python_projects\ANPR_FINAL\anprsys\lib\site-packages\easyocr\model\modules.py:27, in vgg16_bn.__init__(self, pretrained, freeze)
#      25 super(vgg16_bn, self).__init__()
#      26 if version.parse(torchvision.__version__) >= version.parse('0.13'):
# ---> 27     vgg_pretrained_features = models.vgg16_bn(
#      28         weights=models.VGG16_BN_Weights.DEFAULT if pretrained else None
#      29     ).features
#      30 else: #torchvision.__version__ < 0.13
#      31     models.vgg.model_urls['vgg16_bn'] = models.vgg.model_urls['vgg16_bn'].replace('https://', 'http://')
#
# File G:\Users\gui20\python_projects\ANPR_FINAL\anprsys\lib\site-packages\torchvision\models\_utils.py:142, in kwonly_to_pos_or_kw.<locals>.wrapper(*args, **kwargs)
#     135     warnings.warn(
#     136         f"Using {sequence_to_str(tuple(keyword_only_kwargs.keys()), separate_last='and ')} as positional "
#     137         f"parameter(s) is deprecated since 0.13 and may be removed in the future. Please use keyword parameter(s) "
#     138         f"instead."
#     139     )
#     140     kwargs.update(keyword_only_kwargs)
# --> 142 return fn(*args, **kwargs)
#
# File G:\Users\gui20\python_projects\ANPR_FINAL\anprsys\lib\site-packages\torchvision\models\_utils.py:228, in handle_legacy_interface.<locals>.outer_wrapper.<locals>.inner_wrapper(*args, **kwargs)
#     225     del kwargs[pretrained_param]
#     226     kwargs[weights_param] = default_weights_arg
# --> 228 return builder(*args, **kwargs)
#
# File G:\Users\gui20\python_projects\ANPR_FINAL\anprsys\lib\site-packages\torchvision\models\vgg.py:441, in vgg16_bn(weights, progress, **kwargs)
#     421 """VGG-16-BN from `Very Deep Convolutional Networks for Large-Scale Image Recognition <https://arxiv.org/abs/1409.1556>`__.
#     422
#     423 Args:
#    (...)
#     437     :members:
#     438 """
#     439 weights = VGG16_BN_Weights.verify(weights)
# --> 441 return _vgg("D", True, weights, progress, **kwargs)
#
# File G:\Users\gui20\python_projects\ANPR_FINAL\anprsys\lib\site-packages\torchvision\models\vgg.py:103, in _vgg(cfg, batch_norm, weights, progress, **kwargs)
#     101     if weights.meta["categories"] is not None:
#     102         _ovewrite_named_param(kwargs, "num_classes", len(weights.meta["categories"]))
# --> 103 model = VGG(make_layers(cfgs[cfg], batch_norm=batch_norm), **kwargs)
#     104 if weights is not None:
#     105     model.load_state_dict(weights.get_state_dict(progress=progress))
#
# File G:\Users\gui20\python_projects\ANPR_FINAL\anprsys\lib\site-packages\torchvision\models\vgg.py:55, in VGG.__init__(self, features, num_classes, init_weights, dropout)
#      53 for m in self.modules():
#      54     if isinstance(m, nn.Conv2d):
# ---> 55         nn.init.kaiming_normal_(m.weight, mode="fan_out", nonlinearity="relu")
#      56         if m.bias is not None:
#      57             nn.init.constant_(m.bias, 0)
#
# File G:\Users\gui20\python_projects\ANPR_FINAL\anprsys\lib\site-packages\torch\nn\init.py:451, in kaiming_normal_(tensor, a, mode, nonlinearity)
#     449 std = gain / math.sqrt(fan)
#     450 with torch.no_grad():
# --> 451     return tensor.normal_(0, std)
#
# KeyboardInterrupt:
